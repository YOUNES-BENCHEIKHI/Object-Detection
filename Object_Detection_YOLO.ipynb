# %% [markdown]
# How to create a video from images

# %%
import cv2
import os

images_folder = r"C:\Users\hp\Desktop\Master S3\Analyse vedio, image medicale\images"

output_video_path = r"C:\Users\hp\Desktop\Master S3\Analyse vedio, image medicale\images\ta_video.mp4"

image_files = sorted([f for f in os.listdir(images_folder) if f.endswith(('.jpg', '.jpeg', '.png'))])


if not image_files:
    print("Aucune image trouvée dans le dossier.")
    exit()

first_image_path = os.path.join(images_folder, image_files[0])
first_image = cv2.imread(first_image_path)
height, width, _ = first_image.shape

fps = 30  
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec pour MP4
video_writer = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

for image_file in image_files:
    image_path = os.path.join(images_folder, image_file)
    image = cv2.imread(image_path)

    if image is None:
        print(f"Erreur lors de la lecture de l'image : {image_path}")
        continue

    video_writer.write(image)

# Libérer les ressources
video_writer.release()
print(f"Vidéo créée avec succès : {output_video_path}")
# Out:
# Vidéo créée avec succès : C:\Users\hp\Desktop\Master S3\Analyse vedio, image medicale\images\ta_video.mp4

# %% [markdown]
# Detect objects in an image

# %%
from ultralytics import YOLO
import cv2
import math

image_path = r"C:\Users\hp\Desktop\Master S3\Analyse vedio, image medicale\archive\No_Apply_Grayscale\No_Apply_Grayscale\Vehicles_Detection.v8i.coco\test\frame_1004_jpg.rf.a6f441255e54620ea11fb3cf34fc0a97.jpg" 
img = cv2.imread(image_path)

if img is None:
    print("Erreur : Impossible de charger l'image.")
    exit()

model = YOLO("yolo-Weights/yolov8n.pt")
print("Modèle YOLO chargé avec succès.")

# Classes d'objets
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]

results = model(img)

# Parcourir les résultats de détection
for r in results:
    for box in r.boxes:
        x1, y1, x2, y2 = [int(coord) for coord in box.xyxy[0]]
        confidence = math.ceil((box.conf[0] * 100)) / 100
        cls = int(box.cls[0])

        # Dessiner un rectangle autour de l'objet détecté et afficher la classe et la confiance
        cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)
        cv2.putText(img, f"{classNames[cls]} {confidence}", 
                    (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)

# Afficher l'image avec les objets détectés
cv2.imshow("Détection d'objets", img)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Modèle YOLO chargé avec succès.
#
# 0: 640x640 1 person, 14 cars, 1 truck, 227.0ms
# Speed: 8.0ms preprocess, 227.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)

# %% [markdown]
# Detect objects in a video

# %%
from ultralytics import YOLO
import cv2
import math

# Charger la vidéo
video_path = r"C:\Users\hp\Desktop\Master S3\Analyse vedio, image medicale\archive\Sample_Video_HighQuality.mp4"
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print("Erreur : Impossible de charger la vidéo.")
    exit()

# Charger le modèle
model = YOLO("yolo-Weights/yolov8n.pt")
print("Modèle YOLO chargé avec succès.")

# Classes d'objets
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush","pin","stylo"
              ]

while True:
    success, img = cap.read()  # Lire chaque image de la vidéo
    if not success:
        print("Fin de la vidéo ou erreur de lecture.")
        break

    results = model(img, stream=True)  # Faire la détection avec YOLO

    for r in results:
        for box in r.boxes:
            x1, y1, x2, y2 = [int(coord) for coord in box.xyxy[0]]
            confidence = math.ceil((box.conf[0] * 100)) / 100
            cls = int(box.cls[0])

            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)
            cv2.putText(img, f"{classNames[cls]} {confidence}", 
                        (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)

    cv2.imshow("Détection d'objets", img)

    if cv2.waitKey(1) == ord('q'):  # Appuyer sur 'q' pour quitter
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Modèle YOLO chargé avec succès.
#
# 0: 384x640 16 cars, 1 motorcycle, 212.3ms
# Speed: 14.9ms preprocess, 212.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 2 motorcycles, 180.3ms
# Speed: 12.7ms preprocess, 180.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 2 motorcycles, 131.4ms
# Speed: 5.6ms preprocess, 131.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 15 cars, 2 motorcycles, 136.8ms
# Speed: 4.2ms preprocess, 136.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 16 cars, 1 motorcycle, 143.1ms
# Speed: 5.8ms preprocess, 143.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 3 motorcycles, 128.3ms
# Speed: 5.2ms preprocess, 128.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 13 cars, 2 motorcycles, 125.3ms
# Speed: 6.9ms preprocess, 125.3ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 13 cars, 1 motorcycle, 139.6ms
# Speed: 5.8ms preprocess, 139.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 135.4ms
# Speed: 4.7ms preprocess, 135.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 158.6ms
# Speed: 14.5ms preprocess, 158.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 15 cars, 169.5ms
# Speed: 6.1ms preprocess, 169.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 cars, 199.6ms
# Speed: 59.3ms preprocess, 199.6ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 218.8ms
# Speed: 28.4ms preprocess, 218.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 cars, 133.8ms
# Speed: 3.6ms preprocess, 133.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 cars, 138.9ms
# Speed: 1.0ms preprocess, 138.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 200.9ms
# Speed: 3.1ms preprocess, 200.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cars, 152.1ms
# Speed: 5.7ms preprocess, 152.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 cars, 138.0ms
# Speed: 2.2ms preprocess, 138.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 14 cars, 133.4ms
# Speed: 4.9ms preprocess, 133.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# Verify if you can download the video

# %%
cap = cv2.VideoCapture(r"C:\Users\hp\Desktop\Master S3\Analyse vedio, image medicale\images\ta_video.mp4")
if not cap.isOpened():
    print("Error: Unable to open the video.")
else:
    ret, frame = cap.read()
    if ret:
        print("Video loaded successfully.")
        cv2.imshow("Frame", frame)
        cv2.waitKey(0)
    else:
        print("Error: Unable to read frame.")
cap.release()
# Out:
# Video loaded successfully.

# %% [markdown]
# Detect objects using a webcam

# %%
from ultralytics import YOLO
import cv2
import math

# Start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)
model = YOLO("yolo-Weights/yolov8n.pt")

classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush","stylo","pincil"]

while True:
    success, img = cap.read()
    if not success:
        print("Failed to capture frame. Exiting...")
        break

    results = model(img, stream=True)

    for r in results:
        boxes = r.boxes

        for box in boxes:
           
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)  # Convert to int values

            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

           
            confidence = math.ceil((box.conf[0] * 100)) / 100
            print("Confidence --->", confidence)

            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    if img is not None and img.size > 0:
        cv2.imshow('Webcam', img)
    else:
        print("Empty frame detected!")
        break

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 239.1ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 14.6ms preprocess, 239.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 221.3ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 12.6ms preprocess, 221.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 185.9ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 5.0ms preprocess, 185.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 183.5ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 4.6ms preprocess, 183.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 178.2ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 5.8ms preprocess, 178.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 168.1ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.7ms preprocess, 168.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 155.7ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 5.8ms preprocess, 155.7ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 162.1ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.0ms preprocess, 162.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 167.0ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 4.4ms preprocess, 167.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 154.6ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 4.2ms preprocess, 154.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 162.1ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.0ms preprocess, 162.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 157.9ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.3ms preprocess, 157.9ms inference, 15.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 162.4ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 3.5ms preprocess, 162.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tie, 158.6ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.34
# Class name --> tie
# Speed: 3.7ms preprocess, 158.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tie, 155.7ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.35
# Class name --> tie
# Speed: 4.5ms preprocess, 155.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 169.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 5.3ms preprocess, 169.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 158.2ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 3.8ms preprocess, 158.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 159.3ms
# Confidence ---> 0.75
# Class name --> cell phone
# Confidence ---> 0.58
# Class name --> person
# Speed: 2.0ms preprocess, 159.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 1 cell phone, 168.8ms
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.4
# Class name --> laptop
# Confidence ---> 0.37
# Class name --> cell phone
# Speed: 4.2ms preprocess, 168.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 1 cell phone, 166.8ms
# Confidence ---> 0.67
# Class name --> laptop
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.58
# Class name --> cell phone
# Confidence ---> 0.3
# Class name --> person
# Speed: 3.9ms preprocess, 166.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 1 cell phone, 169.9ms
# Confidence ---> 0.81
# Class name --> cell phone
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.39
# Class name --> laptop
# Confidence ---> 0.29
# Class name --> person
# Speed: 2.5ms preprocess, 169.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 161.0ms
# Confidence ---> 0.96
# Class name --> cell phone
# Confidence ---> 0.84
# Class name --> person
# Speed: 2.5ms preprocess, 161.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 159.4ms
# Confidence ---> 0.94
# Class name --> cell phone
# Confidence ---> 0.83
# Class name --> person
# Speed: 3.7ms preprocess, 159.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 168.7ms
# Confidence ---> 0.94
# Class name --> cell phone
# Confidence ---> 0.86
# Class name --> person
# Speed: 3.4ms preprocess, 168.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 286.3ms
# Confidence ---> 0.94
# Class name --> cell phone
# Confidence ---> 0.86
# Class name --> person
# Speed: 2.1ms preprocess, 286.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 169.5ms
# Confidence ---> 0.93
# Class name --> cell phone
# Confidence ---> 0.85
# Class name --> person
# Speed: 3.7ms preprocess, 169.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 167.4ms
# Confidence ---> 0.95
# Class name --> cell phone
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.29
# Class name --> cell phone
# Speed: 4.6ms preprocess, 167.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 163.8ms
# Confidence ---> 0.95
# Class name --> cell phone
# Confidence ---> 0.88
# Class name --> person
# Speed: 4.9ms preprocess, 163.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 163.6ms
# Confidence ---> 0.93
# Class name --> cell phone
# Confidence ---> 0.86
# Class name --> person
# Speed: 6.5ms preprocess, 163.6ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 158.8ms
# Confidence ---> 0.93
# Class name --> cell phone
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.4ms preprocess, 158.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 158.2ms
# Confidence ---> 0.94
# Class name --> cell phone
# Confidence ---> 0.84
# Class name --> person
# Speed: 2.7ms preprocess, 158.2ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 157.7ms
# Confidence ---> 0.92
# Class name --> cell phone
# Confidence ---> 0.85
# Class name --> person
# Speed: 3.5ms preprocess, 157.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 155.9ms
# Confidence ---> 0.94
# Class name --> cell phone
# Confidence ---> 0.85
# Class name --> person
# Speed: 3.9ms preprocess, 155.9ms inference, 15.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 152.8ms
# Confidence ---> 0.91
# Class name --> cell phone
# Confidence ---> 0.79
# Class name --> person
# Speed: 5.0ms preprocess, 152.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 155.2ms
# Confidence ---> 0.92
# Class name --> cell phone
# Confidence ---> 0.84
# Class name --> person
# Speed: 4.9ms preprocess, 155.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 155.3ms
# Confidence ---> 0.95
# Class name --> cell phone
# Confidence ---> 0.8
# Class name --> person
# Speed: 3.0ms preprocess, 155.3ms inference, 16.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 160.7ms
# Confidence ---> 0.94
# Class name --> cell phone
# Confidence ---> 0.86
# Class name --> person
# Speed: 6.1ms preprocess, 160.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tie, 1 cell phone, 157.6ms
# Confidence ---> 0.94
# Class name --> cell phone
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.27
# Class name --> tie
# Speed: 1.0ms preprocess, 157.6ms inference, 16.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 171.6ms
# Confidence ---> 0.93
# Class name --> cell phone
# Confidence ---> 0.84
# Class name --> person
# Speed: 1.0ms preprocess, 171.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 172.1ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.0ms preprocess, 172.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tie, 1 cell phone, 300.6ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.32
# Class name --> tie
# Confidence ---> 0.27
# Class name --> cell phone
# Speed: 0.0ms preprocess, 300.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 192.8ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.3ms preprocess, 192.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 172.1ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 5.8ms preprocess, 172.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 175.2ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 175.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 167.4ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 4.9ms preprocess, 167.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 184.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 184.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 191.8ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.0ms preprocess, 191.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 175.9ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.0ms preprocess, 175.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 167.3ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 4.4ms preprocess, 167.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 165.8ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.0ms preprocess, 165.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 162.5ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 3.7ms preprocess, 162.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 168.2ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.9ms preprocess, 168.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 177.6ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.0ms preprocess, 177.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 166.0ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.0ms preprocess, 166.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 171.3ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.0ms preprocess, 171.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 174.7ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.0ms preprocess, 174.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 160.2ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 2.8ms preprocess, 160.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 168.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 3.5ms preprocess, 168.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 157.6ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 3.5ms preprocess, 157.6ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 163.8ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 0.0ms preprocess, 163.8ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 161.5ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 4.3ms preprocess, 161.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 168.3ms
# Confidence ---> 0.95
# Class name --> person
# Speed: 0.0ms preprocess, 168.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 166.9ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.0ms preprocess, 166.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 160.3ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.0ms preprocess, 160.3ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 176.2ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.0ms preprocess, 176.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 166.3ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 166.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 161.8ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.3
# Class name --> toothbrush
# Speed: 1.0ms preprocess, 161.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 170.1ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.0ms preprocess, 170.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 183.0ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.3ms preprocess, 183.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 305.2ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.8ms preprocess, 305.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 181.0ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 181.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 171.2ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.27
# Class name --> toothbrush
# Speed: 0.0ms preprocess, 171.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 162.5ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.9ms preprocess, 162.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 toothbrush, 161.7ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.38
# Class name --> toothbrush
# Speed: 2.6ms preprocess, 161.7ms inference, 17.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 166.6ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 166.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 baseball bat, 162.7ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.35
# Class name --> baseball bat
# Speed: 0.0ms preprocess, 162.7ms inference, 15.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 baseball bat, 174.4ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.44
# Class name --> baseball bat
# Speed: 0.0ms preprocess, 174.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 baseball bat, 170.5ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.44
# Class name --> baseball bat
# Speed: 4.1ms preprocess, 170.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 baseball bat, 1 scissors, 162.7ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.33
# Class name --> baseball bat
# Confidence ---> 0.27
# Class name --> scissors
# Speed: 0.0ms preprocess, 162.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 baseball bat, 164.7ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.41
# Class name --> baseball bat
# Speed: 1.0ms preprocess, 164.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 baseball bat, 165.2ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.63
# Class name --> baseball bat
# Speed: 2.8ms preprocess, 165.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 baseball bat, 174.5ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.52
# Class name --> baseball bat
# Speed: 2.4ms preprocess, 174.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 baseball bat, 159.1ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.27
# Class name --> baseball bat
# Speed: 5.7ms preprocess, 159.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 baseball bat, 164.3ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.43
# Class name --> baseball bat
# Speed: 1.0ms preprocess, 164.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 baseball bat, 164.1ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.53
# Class name --> baseball bat
# Speed: 5.1ms preprocess, 164.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 baseball bat, 178.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.38
# Class name --> baseball bat
# Speed: 0.0ms preprocess, 178.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 baseball bat, 166.6ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.35
# Class name --> baseball bat
# Speed: 1.0ms preprocess, 166.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 baseball bat, 166.7ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.39
# Class name --> baseball bat
# Speed: 5.4ms preprocess, 166.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 baseball bat, 165.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.51
# Class name --> baseball bat
# Speed: 2.0ms preprocess, 165.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 160.0ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.3ms preprocess, 160.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 178.2ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 4.9ms preprocess, 178.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 baseball bat, 302.2ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.36
# Class name --> baseball bat
# Speed: 3.6ms preprocess, 302.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 baseball bat, 166.5ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.32
# Class name --> baseball bat
# Speed: 4.0ms preprocess, 166.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 179.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 179.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 193.7ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.2ms preprocess, 193.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 176.4ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 176.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 baseball bat, 173.4ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.36
# Class name --> baseball bat
# Speed: 0.0ms preprocess, 173.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 baseball bat, 196.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.32
# Class name --> baseball bat
# Speed: 1.0ms preprocess, 196.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 baseball bat, 175.1ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.35
# Class name --> baseball bat
# Speed: 3.3ms preprocess, 175.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 baseball bat, 177.3ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.36
# Class name --> baseball bat
# Speed: 0.0ms preprocess, 177.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 baseball bat, 173.4ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.35
# Class name --> baseball bat
# Speed: 5.0ms preprocess, 173.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 baseball bat, 1 tennis racket, 165.3ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.33
# Class name --> tennis racket
# Confidence ---> 0.29
# Class name --> baseball bat
# Speed: 6.0ms preprocess, 165.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 baseball bat, 159.4ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.46
# Class name --> baseball bat
# Speed: 0.0ms preprocess, 159.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tennis racket, 176.7ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.27
# Class name --> tennis racket
# Speed: 0.0ms preprocess, 176.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 baseball bat, 1 tennis racket, 204.5ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.44
# Class name --> tennis racket
# Confidence ---> 0.28
# Class name --> baseball bat
# Speed: 0.0ms preprocess, 204.5ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 baseball bat, 1 tennis racket, 164.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.39
# Class name --> baseball bat
# Confidence ---> 0.31
# Class name --> tennis racket
# Speed: 0.0ms preprocess, 164.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 baseball bat, 171.2ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.38
# Class name --> baseball bat
# Speed: 4.0ms preprocess, 171.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 162.3ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.7ms preprocess, 162.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 168.7ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 0.0ms preprocess, 168.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 342.7ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.0ms preprocess, 342.7ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 178.8ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.36
# Class name --> cell phone
# Speed: 0.0ms preprocess, 178.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 163.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.35
# Class name --> cell phone
# Speed: 3.3ms preprocess, 163.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 182.5ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.46
# Class name --> cell phone
# Speed: 5.1ms preprocess, 182.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 166.1ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.35
# Class name --> cell phone
# Speed: 3.8ms preprocess, 166.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 175.2ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.55
# Class name --> cell phone
# Speed: 0.0ms preprocess, 175.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 175.2ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.32
# Class name --> cell phone
# Speed: 0.0ms preprocess, 175.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 172.1ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.39
# Class name --> cell phone
# Speed: 3.5ms preprocess, 172.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 178.5ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.31
# Class name --> cell phone
# Speed: 1.9ms preprocess, 178.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 176.2ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.28
# Class name --> cell phone
# Speed: 0.0ms preprocess, 176.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 187.1ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 187.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 162.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.0ms preprocess, 162.0ms inference, 16.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 183.1ms
# Confidence ---> 0.65
# Class name --> person
# Speed: 0.0ms preprocess, 183.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 174.5ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 3.7ms preprocess, 174.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 164.4ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 7.2ms preprocess, 164.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 314.7ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.5
# Class name --> cell phone
# Speed: 0.0ms preprocess, 314.7ms inference, 11.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 171.2ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 5.3ms preprocess, 171.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 165.6ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.0ms preprocess, 165.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 172.2ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 4.3ms preprocess, 172.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 170.8ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 170.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 178.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.0ms preprocess, 178.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 177.7ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.0ms preprocess, 177.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 160.6ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.0ms preprocess, 160.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 166.5ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 4.5ms preprocess, 166.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 181.6ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 181.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 184.5ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.5ms preprocess, 184.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 170.5ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.6ms preprocess, 170.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 175.9ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.0ms preprocess, 175.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 170.2ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 2.4ms preprocess, 170.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 308.2ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 5.9ms preprocess, 308.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 176.9ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 176.9ms inference, 8.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 165.2ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.0ms preprocess, 165.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 178.2ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 178.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 180.9ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.0ms preprocess, 180.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 170.5ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.27
# Class name --> cell phone
# Speed: 2.4ms preprocess, 170.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 186.5ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.0ms preprocess, 186.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 184.6ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 5.0ms preprocess, 184.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 165.8ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 4.8ms preprocess, 165.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 183.9ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 183.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.8ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 7.1ms preprocess, 209.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 178.2ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 3.6ms preprocess, 178.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 169.8ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 3.4ms preprocess, 169.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 311.7ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.2ms preprocess, 311.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 162.6ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.0ms preprocess, 162.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 176.4ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 3.4ms preprocess, 176.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 180.7ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.6ms preprocess, 180.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 165.4ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 1.5ms preprocess, 165.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 179.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.0ms preprocess, 179.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 182.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.0ms preprocess, 182.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 183.8ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.0ms preprocess, 183.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 172.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.27
# Class name --> cell phone
# Speed: 3.2ms preprocess, 172.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 180.9ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.0ms preprocess, 180.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 180.9ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 180.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 166.5ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.7ms preprocess, 166.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 308.1ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.0ms preprocess, 308.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 175.6ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 4.5ms preprocess, 175.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 173.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.0ms preprocess, 173.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 166.7ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.3ms preprocess, 166.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 176.4ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 176.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 173.1ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 173.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 174.2ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 5.3ms preprocess, 174.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 161.5ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.4ms preprocess, 161.5ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 173.9ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.0ms preprocess, 173.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 173.9ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.4ms preprocess, 173.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 176.7ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 3.8ms preprocess, 176.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 183.7ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.0ms preprocess, 183.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 319.3ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 5.3ms preprocess, 319.3ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 159.7ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 4.5ms preprocess, 159.7ms inference, 16.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 174.6ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.5ms preprocess, 174.6ms inference, 8.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 172.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.0ms preprocess, 172.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 176.4ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.2ms preprocess, 176.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 170.4ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.0ms preprocess, 170.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 178.9ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.0ms preprocess, 178.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 165.5ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.8ms preprocess, 165.5ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 174.3ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 174.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 180.3ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.32
# Class name --> cell phone
# Speed: 0.0ms preprocess, 180.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 191.6ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 3.2ms preprocess, 191.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 318.2ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 5.9ms preprocess, 318.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 186.1ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.34
# Class name --> cell phone
# Speed: 0.0ms preprocess, 186.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 169.3ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.0ms preprocess, 169.3ms inference, 7.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 174.9ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 174.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 179.2ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 3.6ms preprocess, 179.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 179.3ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 3.5ms preprocess, 179.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 170.4ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.35
# Class name --> cell phone
# Speed: 3.6ms preprocess, 170.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 182.0ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.0ms preprocess, 182.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 175.9ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.0ms preprocess, 175.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 176.4ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 3.4ms preprocess, 176.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 337.5ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 4.5ms preprocess, 337.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 183.5ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 9.3ms preprocess, 183.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 178.2ms
# Confidence ---> 0.76
# Class name --> person
# Speed: 1.0ms preprocess, 178.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 180.0ms
# Confidence ---> 0.76
# Class name --> person
# Speed: 0.0ms preprocess, 180.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 169.9ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 4.1ms preprocess, 169.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 177.3ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 5.6ms preprocess, 177.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tie, 182.3ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.41
# Class name --> tie
# Speed: 1.0ms preprocess, 182.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 178.2ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 3.6ms preprocess, 178.2ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 182.6ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.4
# Class name --> cup
# Speed: 0.0ms preprocess, 182.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 174.3ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.35
# Class name --> cup
# Speed: 5.1ms preprocess, 174.3ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tie, 314.2ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.41
# Class name --> tie
# Speed: 1.0ms preprocess, 314.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 183.6ms
# Confidence ---> 0.94
# Class name --> person
# Speed: 0.0ms preprocess, 183.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 186.0ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 186.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 185.5ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.34
# Class name --> cup
# Speed: 0.0ms preprocess, 185.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cups, 177.8ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.44
# Class name --> cup
# Confidence ---> 0.35
# Class name --> cup
# Speed: 1.0ms preprocess, 177.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cups, 180.8ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.71
# Class name --> cup
# Confidence ---> 0.35
# Class name --> cup
# Speed: 3.2ms preprocess, 180.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 180.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.74
# Class name --> cup
# Speed: 1.0ms preprocess, 180.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 177.9ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.79
# Class name --> cup
# Speed: 3.5ms preprocess, 177.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 177.2ms
# Confidence ---> 0.78
# Class name --> cup
# Confidence ---> 0.65
# Class name --> person
# Speed: 0.0ms preprocess, 177.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 wine glass, 1 cup, 183.2ms
# Confidence ---> 0.8
# Class name --> cup
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.43
# Class name --> wine glass
# Speed: 0.0ms preprocess, 183.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 341.0ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.7
# Class name --> cup
# Speed: 0.0ms preprocess, 341.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 wine glass, 1 cup, 183.4ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.8
# Class name --> cup
# Confidence ---> 0.35
# Class name --> wine glass
# Speed: 0.0ms preprocess, 183.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 wine glass, 1 cup, 174.4ms
# Confidence ---> 0.83
# Class name --> cup
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.35
# Class name --> wine glass
# Speed: 2.8ms preprocess, 174.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 188.3ms
# Confidence ---> 0.67
# Class name --> cup
# Confidence ---> 0.62
# Class name --> person
# Speed: 1.0ms preprocess, 188.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 wine glass, 1 cup, 187.5ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.69
# Class name --> cup
# Confidence ---> 0.28
# Class name --> wine glass
# Speed: 0.0ms preprocess, 187.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 187.2ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.72
# Class name --> cup
# Speed: 0.0ms preprocess, 187.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 183.0ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.7
# Class name --> cup
# Speed: 0.0ms preprocess, 183.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 178.7ms
# Confidence ---> 0.8
# Class name --> cup
# Confidence ---> 0.78
# Class name --> person
# Speed: 0.0ms preprocess, 178.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 186.1ms
# Confidence ---> 0.83
# Class name --> cup
# Confidence ---> 0.71
# Class name --> person
# Speed: 0.0ms preprocess, 186.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 303.5ms
# Confidence ---> 0.83
# Class name --> cup
# Confidence ---> 0.8
# Class name --> person
# Speed: 1.0ms preprocess, 303.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 wine glass, 1 cup, 180.6ms
# Confidence ---> 0.84
# Class name --> cup
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.27
# Class name --> wine glass
# Speed: 5.9ms preprocess, 180.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 184.1ms
# Confidence ---> 0.81
# Class name --> cup
# Confidence ---> 0.68
# Class name --> person
# Speed: 2.7ms preprocess, 184.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 179.4ms
# Confidence ---> 0.77
# Class name --> cup
# Confidence ---> 0.76
# Class name --> person
# Speed: 1.0ms preprocess, 179.4ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 181.1ms
# Confidence ---> 0.83
# Class name --> cup
# Confidence ---> 0.75
# Class name --> person
# Speed: 1.0ms preprocess, 181.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 186.9ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.73
# Class name --> cup
# Speed: 4.9ms preprocess, 186.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 180.9ms
# Confidence ---> 0.82
# Class name --> cup
# Confidence ---> 0.76
# Class name --> person
# Speed: 1.0ms preprocess, 180.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 wine glass, 1 cup, 179.4ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.83
# Class name --> cup
# Confidence ---> 0.28
# Class name --> wine glass
# Speed: 3.5ms preprocess, 179.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 343.2ms
# Confidence ---> 0.89
# Class name --> cup
# Confidence ---> 0.79
# Class name --> person
# Speed: 2.0ms preprocess, 343.2ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 180.2ms
# Confidence ---> 0.87
# Class name --> cup
# Confidence ---> 0.79
# Class name --> person
# Speed: 3.8ms preprocess, 180.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 175.9ms
# Confidence ---> 0.78
# Class name --> cup
# Confidence ---> 0.63
# Class name --> person
# Speed: 4.9ms preprocess, 175.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 1 cell phone, 180.1ms
# Confidence ---> 0.82
# Class name --> cup
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.26
# Class name --> cell phone
# Speed: 0.0ms preprocess, 180.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 181.7ms
# Confidence ---> 0.78
# Class name --> cup
# Confidence ---> 0.62
# Class name --> person
# Speed: 0.0ms preprocess, 181.7ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 188.7ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.71
# Class name --> cup
# ...
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.28
# Class name --> cell phone
# Speed: 2.5ms preprocess, 332.3ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.1ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 6.3ms preprocess, 210.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 182.4ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.31
# Class name --> cell phone
# Speed: 3.4ms preprocess, 182.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 174.4ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.3
# Class name --> cell phone
# Speed: 3.4ms preprocess, 174.4ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 186.8ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.26
# Class name --> cell phone
# Speed: 0.0ms preprocess, 186.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 176.4ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.38
# Class name --> cell phone
# Speed: 2.0ms preprocess, 176.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 180.4ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.34
# Class name --> cell phone
# Speed: 2.3ms preprocess, 180.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 179.6ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.4ms preprocess, 179.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 174.9ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 5.1ms preprocess, 174.9ms inference, 72.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 217.6ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.3
# Class name --> cell phone
# Speed: 70.2ms preprocess, 217.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 177.4ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.6ms preprocess, 177.4ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 182.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 0.0ms preprocess, 182.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 174.5ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 5.8ms preprocess, 174.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 172.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.33
# Class name --> cell phone
# Speed: 4.2ms preprocess, 172.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 175.6ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 2.1ms preprocess, 175.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 179.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.39
# Class name --> cell phone
# Speed: 0.0ms preprocess, 179.0ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 175.9ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.29
# Class name --> cell phone
# Speed: 2.6ms preprocess, 175.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 342.4ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 342.4ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 180.9ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.31
# Class name --> cell phone
# Speed: 29.8ms preprocess, 180.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 174.6ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 5.6ms preprocess, 174.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 174.0ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 4.3ms preprocess, 174.0ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 185.6ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.0ms preprocess, 185.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 180.5ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.0ms preprocess, 180.5ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 178.5ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.0ms preprocess, 178.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 177.2ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 177.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 181.6ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 181.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 380.8ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 5.1ms preprocess, 380.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 181.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 2.0ms preprocess, 181.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 182.6ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 3.3ms preprocess, 182.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 175.4ms
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 3.0ms preprocess, 175.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 177.9ms
# Confidence ---> 0.8
# Class name --> cell phone
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.35
# Class name --> cell phone
# Speed: 2.0ms preprocess, 177.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 181.6ms
# Confidence ---> 0.64
# Class name --> cell phone
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.28
# Class name --> cell phone
# Speed: 0.0ms preprocess, 181.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 174.7ms
# Confidence ---> 0.87
# Class name --> cell phone
# Confidence ---> 0.62
# Class name --> person
# Speed: 4.8ms preprocess, 174.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 176.6ms
# Confidence ---> 0.87
# Class name --> cell phone
# Confidence ---> 0.54
# Class name --> person
# Speed: 0.0ms preprocess, 176.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 330.7ms
# Confidence ---> 0.83
# Class name --> cell phone
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Speed: 3.4ms preprocess, 330.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 208.6ms
# Confidence ---> 0.79
# Class name --> cell phone
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 5.1ms preprocess, 208.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 174.8ms
# Confidence ---> 0.73
# Class name --> cell phone
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 3.6ms preprocess, 174.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 171.7ms
# Confidence ---> 0.85
# Class name --> cell phone
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.28
# Class name --> cell phone
# Speed: 3.4ms preprocess, 171.7ms inference, 7.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cell phones, 180.4ms
# Confidence ---> 0.79
# Class name --> cell phone
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.36
# Class name --> cell phone
# Speed: 2.6ms preprocess, 180.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cell phones, 177.5ms
# Confidence ---> 0.85
# Class name --> cell phone
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.37
# Class name --> cell phone
# Speed: 0.0ms preprocess, 177.5ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cell phones, 175.6ms
# Confidence ---> 0.71
# Class name --> cell phone
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.36
# Class name --> cell phone
# Confidence ---> 0.34
# Class name --> person
# Speed: 3.0ms preprocess, 175.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cell phones, 187.6ms
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.53
# Class name --> cell phone
# Confidence ---> 0.26
# Class name --> person
# Confidence ---> 0.26
# Class name --> cell phone
# Speed: 4.5ms preprocess, 187.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 231.6ms
# Confidence ---> 0.69
# Class name --> cell phone
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 4.3ms preprocess, 231.6ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 349.0ms
# Confidence ---> 0.83
# Class name --> cell phone
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 1.0ms preprocess, 349.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cell phones, 181.5ms
# Confidence ---> 0.73
# Class name --> cell phone
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.4
# Class name --> cell phone
# Confidence ---> 0.28
# Class name --> person
# Speed: 18.6ms preprocess, 181.5ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 183.3ms
# Confidence ---> 0.67
# Class name --> cell phone
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Speed: 1.0ms preprocess, 183.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 183.3ms
# Confidence ---> 0.71
# Class name --> cell phone
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Speed: 0.0ms preprocess, 183.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cell phone, 174.9ms
# Confidence ---> 0.77
# Class name --> cell phone
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 3.1ms preprocess, 174.9ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 183.5ms
# Confidence ---> 0.69
# Class name --> cell phone
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Speed: 2.4ms preprocess, 183.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cell phone, 184.4ms
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.48
# Class name --> cell phone
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 0.0ms preprocess, 184.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 180.8ms
# Confidence ---> 0.8
# Class name --> cell phone
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 3.5ms preprocess, 180.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 remote, 1 cell phone, 181.3ms
# Confidence ---> 0.79
# Class name --> cell phone
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.28
# Class name --> remote
# Speed: 0.0ms preprocess, 181.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 370.4ms
# Confidence ---> 0.7
# Class name --> cell phone
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Speed: 2.6ms preprocess, 370.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 178.2ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 178.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 178.3ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.8ms preprocess, 178.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 173.2ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 1.8ms preprocess, 173.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 182.1ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 1.0ms preprocess, 182.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 173.2ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.26
# Class name --> cell phone
# Speed: 2.8ms preprocess, 173.2ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 179.5ms
# Confidence ---> 0.92
# Class name --> person
# Speed: 0.0ms preprocess, 179.5ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 179.0ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.5ms preprocess, 179.0ms inference, 7.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 191.6ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 191.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 415.5ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.3
# Class name --> cell phone
# Speed: 1.0ms preprocess, 415.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 241.2ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 3.5ms preprocess, 241.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 213.5ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 213.5ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 191.2ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.29
# Class name --> cell phone
# Speed: 0.0ms preprocess, 191.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 283.7ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 22.8ms preprocess, 283.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 264.4ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 19.7ms preprocess, 264.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 347.4ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.35
# Class name --> cell phone
# Speed: 2.0ms preprocess, 347.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 209.2ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.27
# Class name --> cell phone
# Speed: 1.1ms preprocess, 209.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.9ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 1.0ms preprocess, 209.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 197.8ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 4.9ms preprocess, 197.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 196.2ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.9ms preprocess, 196.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
